# %% [markdown]
# # COGS 138 — Neural Data Science
# ## Group 7 Final Project
# ### Are electrophysiological features from the Allen Cell Types Database reflected in resting-state EEG biomarkers for MDD?
#
# **Group Members:** Jessica Truong, Siddhant Gulati, Tony Zheng
# **Dataset 1:** Allen Cell Types Database (mouse cortical neurons)
# **Dataset 2:** MODMA Resting-State EEG (MDD patients vs healthy controls)
#
# ---
# ### Project Overview
# This notebook investigates whether micro-scale electrophysiological features (firing rate, action potential amplitude, inter-spike interval) from mouse cortical neurons in the Allen Cell Types Database correlate with macro-scale EEG biomarkers (alpha power, frontal asymmetry) used to decode Major Depressive Disorder (MDD) in humans.

# %% [markdown]
# ---
# ## 0. Install & Import Libraries

# %%
# Run this cell first to install required packages


# Then update your data path to:
DATA_PATH = '/content/drive/MyDrive/modma_data/'
# !pip install allensdk 
# !pip install mne 
# !pip install scipy scikit-learn seaborn
# Out:
# Requirement already satisfied: allensdk in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (2.16.2)
# Requirement already satisfied: psycopg2-binary in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.9.12)
# Requirement already satisfied: hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.* in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (4.3.1)
# Requirement already satisfied: h5py in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.14.0)
# Requirement already satisfied: matplotlib in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.9.4)
# Requirement already satisfied: numpy<1.24 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.23.5)
# Requirement already satisfied: pandas==1.5.3 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.5.3)
# Requirement already satisfied: jinja2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.1.6)
# Requirement already satisfied: scipy<1.11 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.10.1)
# Requirement already satisfied: six in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.17.0)
# Requirement already satisfied: pynrrd in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.1.3)
# Requirement already satisfied: future in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.0.0)
# Requirement already satisfied: requests in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.32.5)
# Requirement already satisfied: requests-toolbelt in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.0.0)
# Requirement already satisfied: simplejson in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (4.1.1)
# Requirement already satisfied: scikit-image in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.24.0)
# Requirement already satisfied: scikit-build in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.19.0)
# Requirement already satisfied: statsmodels in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.14.6)
# Requirement already satisfied: simpleitk in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.5.5)
# Requirement already satisfied: argschema in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.0.4)
# Requirement already satisfied: glymur in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.14.0.post1)
# Requirement already satisfied: xarray<2023.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2023.1.0)
# Requirement already satisfied: pynwb in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.8.3)
# Requirement already satisfied: tables in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.9.2)
# Requirement already satisfied: seaborn in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.13.2)
# Requirement already satisfied: aiohttp in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.13.5)
# Requirement already satisfied: nest-asyncio in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.6.0)
# Requirement already satisfied: tqdm in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (4.67.3)
# Requirement already satisfied: ndx-events in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (0.4.0)
# Requirement already satisfied: boto3 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (1.42.97)
# Requirement already satisfied: semver in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (3.0.4)
# Requirement already satisfied: cachetools in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (6.2.6)
# Requirement already satisfied: sqlalchemy in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.0.50)
# Requirement already satisfied: python-dateutil in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from allensdk) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from pandas==1.5.3->allensdk) (2026.2)
# Requirement already satisfied: packaging>=21.3 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from xarray<2023.2.0->allensdk) (26.2)
# Requirement already satisfied: jsonschema>=3.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (4.25.1)
# Requirement already satisfied: ruamel-yaml>=0.16 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (0.19.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jsonschema>=3.2.0->hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jsonschema>=3.2.0->hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jsonschema>=3.2.0->hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jsonschema>=3.2.0->hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (0.27.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from referencing>=0.28.4->jsonschema>=3.2.0->hdmf!=3.5.*,!=3.6.*,!=3.7.*,!=3.8.*->allensdk) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from aiohttp->allensdk) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp->allensdk) (3.17)
# Requirement already satisfied: marshmallow<4.0,>=3.0.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from argschema->allensdk) (3.26.2)
# Requirement already satisfied: pyyaml in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from argschema->allensdk) (6.0.3)
# Requirement already satisfied: botocore<1.43.0,>=1.42.97 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from boto3->allensdk) (1.42.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from boto3->allensdk) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from boto3->allensdk) (0.16.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from botocore<1.43.0,>=1.42.97->boto3->allensdk) (1.26.20)
# Requirement already satisfied: lxml in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from glymur->allensdk) (6.1.1)
# Requirement already satisfied: imageio in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from glymur->allensdk) (2.37.2)
# Requirement already satisfied: pillow>=8.3.2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from imageio->glymur->allensdk) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jinja2->allensdk) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib->allensdk) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->allensdk) (3.23.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests->allensdk) (3.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests->allensdk) (2026.5.20)
# Requirement already satisfied: distro in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-build->allensdk) (1.9.0)
# Requirement already satisfied: setuptools>=42.0.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-build->allensdk) (58.0.4)
# Requirement already satisfied: tomli in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-build->allensdk) (2.4.1)
# Requirement already satisfied: wheel>=0.32.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-build->allensdk) (0.47.0)
# Requirement already satisfied: networkx>=2.8 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-image->allensdk) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-image->allensdk) (2024.8.30)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-image->allensdk) (0.5)
# Requirement already satisfied: patsy>=0.5.6 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from statsmodels->allensdk) (1.0.2)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from tables->allensdk) (2.10.2)
# Requirement already satisfied: py-cpuinfo in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from tables->allensdk) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from tables->allensdk) (2.5.1)
# Requirement already satisfied: ndindex>=1.4 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from blosc2>=2.3.0->tables->allensdk) (1.10.1)
# Requirement already satisfied: msgpack in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from blosc2>=2.3.0->tables->allensdk) (1.1.2)
# Requirement already satisfied: mne in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: decorator in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (5.3.1)
# Requirement already satisfied: jinja2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (0.5)
# Requirement already satisfied: matplotlib>=3.6 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (3.9.4)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (1.23.5)
# Requirement already satisfied: packaging in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (26.2)
# Requirement already satisfied: pooch>=1.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (1.9.0)
# Requirement already satisfied: scipy>=1.9 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (1.10.1)
# Requirement already satisfied: tqdm in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from mne) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->mne) (3.23.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from pooch>=1.5->mne) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from pooch>=1.5->mne) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2026.5.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from jinja2->mne) (3.0.3)
# Requirement already satisfied: scipy in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: scikit-learn in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: seaborn in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scipy) (1.23.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in /Users/siddhantgulati/Documents/GitHub/TritonNeuroTech-EMG-Prosthetics/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests

# Allen SDK
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.ephys.ephys_extractor import EphysSweepFeatureExtractor

# EEG processing
import mne

# ML
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# Settings
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 5)

print('All libraries loaded successfully!')
# Out:
# All libraries loaded successfully!

# %% [markdown]
# ---
# ## PART 1: Allen Cell Types Database
# ### 1.1 Load Cell Data via SDK

# %%
# Initialize the cache — data will download to 'cell_types/' folder
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# Get all cells with human-readable metadata
cells = ctc.get_cells()
cells_df = pd.DataFrame(cells)

print(f'Total cells in database: {len(cells_df)}')
print(f'\nColumns available:')
print(cells_df.columns.tolist())
# Out:
# Total cells in database: 2333
#
# Columns available:
# ['reporter_status', 'cell_soma_location', 'species', 'id', 'name', 'structure_layer_name', 'structure_area_id', 'structure_area_abbrev', 'transgenic_line', 'dendrite_type', 'apical', 'reconstruction_type', 'disease_state', 'donor_id', 'structure_hemisphere', 'normalized_depth']

# %%
# Preview the dataframe
cells_df.head()
# Out:
#   reporter_status                                 cell_soma_location  \
# 0            None                              [273.0, 354.0, 216.0]
# 1        positive  [8966.56330957526, 1429.52689052075, 8567.3896...
# 2        positive  [7872.53138541818, 993.212032389272, 3127.1530...
# 3            None                                [69.0, 254.0, 96.0]
# 4        positive       [9400.0, 1520.74232706376, 2188.13845194139]
#
#         species         id                                               name  \
# 0  Homo Sapiens  525011903                                H16.03.003.01.14.02
# 1  Mus musculus  565871768                   Oxtr-2A-Cre;Ai14-293837.03.01.02
# 2  Mus musculus  469801138                Pvalb-IRES-Cre;Ai14-170927.05.02.01
# 3  Homo Sapiens  528642047                             H16.06.009.01.02.06.05
# 4  Mus musculus  605889373  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-337419.0...
#
#   structure_layer_name  structure_area_id structure_area_abbrev  \
# 0                    3              12113                  FroL
# 1                    5                385                  VISp
# 2                    4                385                  VISp
# 3                    5              12141                   MTG
# 4                  2/3                385                  VISp
#
#                     transgenic_line dendrite_type  apical reconstruction_type  \
# 0                                           spiny  intact                None
# 1                      Oxtr-T2A-Cre        aspiny      NA                None
# 2                    Pvalb-IRES-Cre        aspiny      NA                None
# 3                                          aspiny      NA                None
# 4  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre        aspiny      NA                None
#
#   disease_state   donor_id structure_hemisphere  normalized_depth
# 0      epilepsy  524848408                right               NaN
# 1                563340157                 left          0.582057
# 2                319194354                right          0.469578
# 3      epilepsy  528574320                 left               NaN
# 4                605622695                right               NaN

# %% [markdown]
# ### 1.2 Extract Electrophysiological Features

# %%
# Get electrophysiology features for all cells
ephys_features = ctc.get_ephys_features()
ephys_df = pd.DataFrame(ephys_features)

print(f'Ephys feature records: {len(ephys_df)}')
print(f'\nKey features available:')

# Features of interest for our project
features_of_interest = [
    'specimen_id',
    'avg_firing_rate',           # Average firing rate (Hz)
    'f_i_curve_slope',           # Firing rate vs current slope
    'adaptation',                # Spike frequency adaptation
    'mean_isi',                  # Mean inter-spike interval
    'cv_isi',                    # Coefficient of variation of ISI
    'peak_v_long_square',        # Action potential peak voltage (amplitude)
    'trough_v_long_square',      # AP trough voltage
    'fast_trough_v_long_square', # Fast trough
    'upstroke_downstroke_ratio_long_square',  # AP shape
    'input_resistance',          # Input resistance (MOhm)
    'tau',                       # Membrane time constant
    'threshold_v_long_square',   # Spike threshold
]

# Keep only features that exist in the dataframe
available_features = [f for f in features_of_interest if f in ephys_df.columns]
ephys_df = ephys_df[available_features]

print(ephys_df.columns.tolist())
ephys_df.head()
# Out:
# Ephys feature records: 2333
#
# Key features available:
# ['specimen_id', 'f_i_curve_slope', 'adaptation', 'peak_v_long_square', 'trough_v_long_square', 'fast_trough_v_long_square', 'upstroke_downstroke_ratio_long_square', 'tau', 'threshold_v_long_square']
#    specimen_id  f_i_curve_slope  adaptation  peak_v_long_square  \
# 0    529878215     8.335459e-02         NaN           47.875004
# 1    548459652    -3.913630e-19         NaN           36.437500
# 2    579978640     5.267857e-01    0.009770           19.937500
# 3    439024551     1.542553e-01   -0.007898           16.437500
# 4    515188639     1.714041e-01    0.022842           28.250002
#
#    trough_v_long_square  fast_trough_v_long_square  \
# 0            -56.593754                 -56.375004
# 1            -55.406254                 -54.000000
# 2            -60.062500                 -59.500000
# 3            -49.406254                 -47.531250
# 4            -53.000004                 -48.437504
#
#    upstroke_downstroke_ratio_long_square        tau  threshold_v_long_square
# 0                               3.029695  20.495034               -39.000000
# 1                               2.441895  25.131172               -40.468754
# 2                               2.023762  18.314883               -44.375004
# 3                               3.105931   7.616164               -30.500000
# 4                               3.285760  34.829629               -34.875000

# %% [markdown]
# ### 1.3 Filter for Cortical Cell Types (Relevant to Depression)

# %%
# Merge cell metadata with ephys features
merged_df = cells_df.merge(ephys_df, left_on='id', right_on='specimen_id', how='inner')

print(f'Merged records: {len(merged_df)}')

# Filter for mouse cortical neurons (most relevant to EEG comparison)
# Focus on visual cortex and prefrontal-like regions
cortical_df = merged_df[merged_df['species'].str.contains('Mus', na=False)].copy()

print(f'Mouse cortical neurons: {len(cortical_df)}')

# Check cell types available
if 'line_name' in cortical_df.columns:
    print(f'\nUnique cell lines: {cortical_df["line_name"].nunique()}')
# Out:
# Merged records: 2333
# Mouse cortical neurons: 1920

# %% [markdown]
# ### 1.4 Exploratory Analysis — Allen Cell Types

# %%
# Distribution of key electrophysiological features
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle('Allen Cell Types: Distribution of Key Electrophysiological Features', fontsize=14)

plot_features = [
    ('avg_firing_rate', 'Average Firing Rate (Hz)'),
    ('mean_isi', 'Mean ISI (ms)'),
    ('peak_v_long_square', 'AP Peak Voltage (mV)'),
    ('input_resistance', 'Input Resistance (MΩ)'),
    ('tau', 'Membrane Time Constant (ms)'),
    ('adaptation', 'Spike Frequency Adaptation'),
]

for ax, (feat, label) in zip(axes.flatten(), plot_features):
    if feat in cortical_df.columns:
        data = cortical_df[feat].dropna()
        ax.hist(data, bins=30, color='steelblue', edgecolor='white', alpha=0.8)
        ax.set_xlabel(label, fontsize=10)
        ax.set_ylabel('Count')
        ax.set_title(f'{label}\n(n={len(data)})')
    else:
        ax.set_visible(False)

plt.tight_layout()
plt.savefig('allen_features_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Correlation heatmap of Allen features
feature_cols = [f for f, _ in plot_features if f in cortical_df.columns]
corr_matrix = cortical_df[feature_cols].corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, square=True, linewidths=0.5)
plt.title('Spearman Correlation — Allen Cell Electrophysiological Features', fontsize=12)
plt.tight_layout()
plt.savefig('allen_correlation_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## PART 2: MODMA EEG Dataset
# ### 2.1 Load EEG Data
#
# > **Note:** Download the MODMA dataset from http://modma.lzu.edu.cn/data/index/
# > Place the EEG files in a folder called `modma_data/` in the same directory as this notebook.
# > If using the OpenNeuro alternative: https://openneuro.org/datasets/ds003478

# %%
import os

# --------------------------------------------------------
# SET YOUR DATA PATH HERE
# --------------------------------------------------------
DATA_PATH = 'modma_data/'  # <-- change this to your actual path

# Check if data exists
if os.path.exists(DATA_PATH):
    files = os.listdir(DATA_PATH)
    print(f'Found {len(files)} files in {DATA_PATH}')
    print(files[:10])
else:
    print('⚠️  Data folder not found!')
    print('Please download MODMA dataset and update DATA_PATH above.')
    print('Download: http://modma.lzu.edu.cn/data/index/')
# Out:
# ⚠️  Data folder not found!
# Please download MODMA dataset and update DATA_PATH above.
# Download: http://modma.lzu.edu.cn/data/index/

# %%
def load_eeg_file(filepath):
    """
    Load a single EEG file using MNE.
    Supports .edf, .bdf, .set (EEGLAB) formats.
    """
    ext = os.path.splitext(filepath)[1].lower()
    
    if ext == '.edf':
        raw = mne.io.read_raw_edf(filepath, preload=True, verbose=False)
    elif ext == '.bdf':
        raw = mne.io.read_raw_bdf(filepath, preload=True, verbose=False)
    elif ext == '.set':
        raw = mne.io.read_raw_eeglab(filepath, preload=True, verbose=False)
    else:
        raise ValueError(f'Unsupported file format: {ext}')
    
    return raw

# Example: load first EEG file
# raw = load_eeg_file(os.path.join(DATA_PATH, files[0]))
# print(raw.info)

# %% [markdown]
# ### 2.2 Preprocessing Pipeline

# %%
def preprocess_eeg(raw, l_freq=1.0, h_freq=40.0, notch_freq=60.0):
    """
    Standard EEG preprocessing pipeline:
    1. Bandpass filter (1-40 Hz)
    2. Notch filter (60 Hz US powerline)
    3. Re-reference to average
    
    Parameters
    ----------
    raw : mne.io.Raw
    l_freq : float, lower bandpass frequency
    h_freq : float, upper bandpass frequency  
    notch_freq : float, powerline noise frequency
    
    Returns
    -------
    raw_filtered : preprocessed MNE Raw object
    """
    raw_filtered = raw.copy()
    
    # Bandpass filter
    raw_filtered.filter(l_freq=l_freq, h_freq=h_freq, verbose=False)
    
    # Notch filter for powerline noise
    raw_filtered.notch_filter(freqs=notch_freq, verbose=False)
    
    # Re-reference to average
    raw_filtered.set_eeg_reference('average', projection=False, verbose=False)
    
    return raw_filtered

print('Preprocessing function defined.')
# Out:
# Preprocessing function defined.

# %% [markdown]
# ### 2.3 Extract EEG Features: Alpha Power & Frontal Asymmetry

# %%
def compute_band_power(raw, band=(8, 12), frontal_channels=None):
    """
    Compute average power in a frequency band using Welch's method.
    
    Parameters
    ----------
    raw : mne.io.Raw
    band : tuple, (low_freq, high_freq) in Hz
    frontal_channels : list of channel names (e.g. ['F3', 'F4', 'Fz'])
    
    Returns
    -------
    band_powers : dict of {channel: power}
    """
    from mne.time_frequency import psd_array_welch
    
    sfreq = raw.info['sfreq']
    
    if frontal_channels:
        raw_pick = raw.copy().pick_channels(frontal_channels, ordered=True)
    else:
        raw_pick = raw.copy()
    
    data = raw_pick.get_data()
    
    psds, freqs = psd_array_welch(
        data,
        sfreq=sfreq,
        fmin=band[0],
        fmax=band[1],
        n_fft=int(sfreq * 2),  # 2-second windows
        verbose=False
    )
    
    # Average power across frequency band
    band_power = psds.mean(axis=1)  # shape: (n_channels,)
    
    ch_names = raw_pick.ch_names
    return dict(zip(ch_names, band_power))


def compute_frontal_alpha_asymmetry(raw, left_ch='F3', right_ch='F4'):
    """
    Compute Frontal Alpha Asymmetry (FAA).
    FAA = ln(right_alpha) - ln(left_alpha)
    Positive FAA = relative left withdrawal (associated with depression)
    
    Parameters
    ----------
    raw : mne.io.Raw
    left_ch : str, left frontal channel name
    right_ch : str, right frontal channel name
    
    Returns
    -------
    faa : float
    """
    try:
        powers = compute_band_power(raw, band=(8, 12),
                                     frontal_channels=[left_ch, right_ch])
        left_alpha = powers.get(left_ch, np.nan)
        right_alpha = powers.get(right_ch, np.nan)
        
        faa = np.log(right_alpha) - np.log(left_alpha)
        return faa
    except Exception as e:
        print(f'FAA computation error: {e}')
        return np.nan


def extract_all_eeg_features(raw):
    """
    Extract all EEG features for one subject.
    
    Returns
    -------
    features : dict
    """
    features = {}
    
    # Alpha band power (8-12 Hz) — averaged across all channels
    alpha_powers = compute_band_power(raw, band=(8, 12))
    features['mean_alpha_power'] = np.mean(list(alpha_powers.values()))
    
    # Theta band power (4-8 Hz)
    theta_powers = compute_band_power(raw, band=(4, 8))
    features['mean_theta_power'] = np.mean(list(theta_powers.values()))
    
    # Beta band power (12-30 Hz)
    beta_powers = compute_band_power(raw, band=(12, 30))
    features['mean_beta_power'] = np.mean(list(beta_powers.values()))
    
    # Frontal alpha asymmetry
    features['frontal_alpha_asymmetry'] = compute_frontal_alpha_asymmetry(raw)
    
    # Theta/alpha ratio (elevated in depression)
    features['theta_alpha_ratio'] = features['mean_theta_power'] / (features['mean_alpha_power'] + 1e-10)
    
    return features

print('EEG feature extraction functions defined.')
# Out:
# EEG feature extraction functions defined.

# %%
def process_all_subjects(data_path, label_file=None):
    """
    Process all EEG files in a directory and extract features.
    
    Parameters
    ----------
    data_path : str, path to EEG files
    label_file : str (optional), path to CSV with subject labels
                 Expected columns: ['subject_id', 'label'] where label: 1=MDD, 0=healthy
    
    Returns
    -------
    features_df : DataFrame with EEG features per subject
    """
    results = []
    eeg_extensions = ['.edf', '.bdf', '.set']
    
    if not os.path.exists(data_path):
        print(f'Data path {data_path} not found. Using synthetic data for demonstration.')
        return None
    
    files = [f for f in os.listdir(data_path) 
             if any(f.endswith(ext) for ext in eeg_extensions)]
    
    print(f'Processing {len(files)} EEG files...')
    
    for i, fname in enumerate(files):
        try:
            fpath = os.path.join(data_path, fname)
            raw = load_eeg_file(fpath)
            raw = preprocess_eeg(raw)
            feats = extract_all_eeg_features(raw)
            feats['subject_id'] = fname.replace('.edf', '').replace('.bdf', '').replace('.set', '')
            results.append(feats)
            
            if (i + 1) % 10 == 0:
                print(f'Processed {i + 1}/{len(files)} files...')
                
        except Exception as e:
            print(f'Error processing {fname}: {e}')
            continue
    
    features_df = pd.DataFrame(results)
    
    # Merge with labels if provided
    if label_file and os.path.exists(label_file):
        labels_df = pd.read_csv(label_file)
        features_df = features_df.merge(labels_df, on='subject_id', how='left')
    
    return features_df


# Run processing (comment out if data not yet downloaded)
# eeg_features_df = process_all_subjects(DATA_PATH, label_file='modma_data/labels.csv')

print('Processing function defined. Uncomment last line when data is downloaded.')
# Out:
# Processing function defined. Uncomment last line when data is downloaded.

# %% [markdown]
# ### 2.4 Synthetic Data Demo
# Run this section to test the pipeline while waiting for the MODMA dataset.

# %%
np.random.seed(42)
n_subjects = 106  # 53 MDD + 53 healthy (MODMA size)
labels = np.array([1]*53 + [0]*53)  # 1=MDD, 0=healthy

# Simulate EEG features with known group differences
# MDD: lower alpha, higher theta, more asymmetry (based on literature)
eeg_features_df = pd.DataFrame({
    'subject_id': [f'sub_{i:03d}' for i in range(n_subjects)],
    'label': labels,
    'mean_alpha_power': np.concatenate([
        np.random.normal(0.8, 0.2, 53),   # MDD: lower alpha
        np.random.normal(1.2, 0.2, 53)    # Healthy: higher alpha
    ]),
    'mean_theta_power': np.concatenate([
        np.random.normal(1.3, 0.3, 53),   # MDD: higher theta
        np.random.normal(0.9, 0.2, 53)    # Healthy: lower theta
    ]),
    'mean_beta_power': np.concatenate([
        np.random.normal(0.6, 0.15, 53),
        np.random.normal(0.7, 0.15, 53)
    ]),
    'frontal_alpha_asymmetry': np.concatenate([
        np.random.normal(0.3, 0.15, 53),  # MDD: positive asymmetry
        np.random.normal(0.0, 0.15, 53)   # Healthy: near zero
    ]),
    'theta_alpha_ratio': np.concatenate([
        np.random.normal(1.7, 0.4, 53),   # MDD: elevated ratio
        np.random.normal(0.8, 0.2, 53)    # Healthy
    ]),
})

print('Synthetic EEG dataset created (replace with real MODMA data):')
print(eeg_features_df.groupby('label').describe().round(3))
# Out:
# Synthetic EEG dataset created (replace with real MODMA data):
#       mean_alpha_power                                                   \
#                  count   mean    std    min    25%    50%    75%    max
# label
# 0                 53.0  1.196  0.175  0.676  1.100  1.193  1.303  1.513
# 1                 53.0  0.755  0.182  0.408  0.656  0.753  0.865  1.170
#
#       mean_theta_power         ... frontal_alpha_asymmetry         \
#                  count   mean  ...                     75%    max
# label                          ...
# 0                 53.0  0.942  ...                   0.146  0.328
# 1                 53.0  1.309  ...                   0.360  0.614
#
#       theta_alpha_ratio
#                   count   mean    std    min    25%    50%    75%    max
# label
# 0                  53.0  0.771  0.205  0.439  0.625  0.762  0.908  1.416
# 1                  53.0  1.629  0.414  0.779  1.314  1.655  1.946  2.486
#
# [2 rows x 40 columns]

# %% [markdown]
# ### 2.5 Visualize EEG Features by Group

# %%
eeg_feature_cols = ['mean_alpha_power', 'mean_theta_power', 
                     'mean_beta_power', 'frontal_alpha_asymmetry', 'theta_alpha_ratio']

fig, axes = plt.subplots(1, 5, figsize=(18, 5))
fig.suptitle('EEG Features: MDD vs Healthy Controls', fontsize=14, fontweight='bold')

colors = {1: '#E74C3C', 0: '#2ECC71'}  # Red=MDD, Green=Healthy
labels_text = {1: 'MDD', 0: 'Healthy'}

for ax, feat in zip(axes, eeg_feature_cols):
    for label_val, color in colors.items():
        data = eeg_features_df[eeg_features_df['label'] == label_val][feat]
        ax.hist(data, bins=20, alpha=0.6, color=color,
                label=labels_text[label_val], edgecolor='white')
    
    # Statistical test
    mdd_data = eeg_features_df[eeg_features_df['label'] == 1][feat]
    hc_data = eeg_features_df[eeg_features_df['label'] == 0][feat]
    t_stat, p_val = stats.ttest_ind(mdd_data, hc_data)
    
    ax.set_title(f'{feat.replace("_", " ").title()}\np={p_val:.3f}', fontsize=9)
    ax.legend(fontsize=8)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.savefig('eeg_features_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## PART 3: Decoding — MDD Classification from EEG
# ### 3.1 Build and Evaluate Classifier

# %%
# Prepare features and labels
X = eeg_features_df[eeg_feature_cols].values
y = eeg_features_df['label'].values

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Cross-validated logistic regression
clf = LogisticRegression(random_state=42, max_iter=1000)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_scores = cross_val_score(clf, X_scaled, y, cv=cv, scoring='accuracy')

print('=== MDD Decoding Results ===')
print(f'Cross-validated accuracy: {cv_scores.mean():.3f} ± {cv_scores.std():.3f}')
print(f'Individual fold scores: {cv_scores.round(3)}')
print(f'\nChance level: 0.500')
print(f'Above chance: {cv_scores.mean() > 0.5}')
# Out:
# === MDD Decoding Results ===
# Cross-validated accuracy: 0.981 ± 0.023
# Individual fold scores: [0.955 0.952 1.    1.    1.   ]
#
# Chance level: 0.500
# Above chance: True

# %%
# Fit final model and inspect feature importance
clf.fit(X_scaled, y)

coef_df = pd.DataFrame({
    'Feature': eeg_feature_cols,
    'Coefficient': clf.coef_[0],
    'Abs_Coefficient': np.abs(clf.coef_[0])
}).sort_values('Abs_Coefficient', ascending=True)

plt.figure(figsize=(8, 4))
colors_bar = ['#E74C3C' if c > 0 else '#3498DB' for c in coef_df['Coefficient']]
plt.barh(coef_df['Feature'], coef_df['Coefficient'], color=colors_bar, edgecolor='white')
plt.axvline(x=0, color='black', linewidth=0.8)
plt.xlabel('Logistic Regression Coefficient')
plt.title('EEG Feature Importance for MDD Decoding\n(Red = predicts MDD, Blue = predicts Healthy)')
plt.tight_layout()
plt.savefig('feature_importance.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## PART 4: Cross-Scale Correlation
# ### 4.1 Compute Summary Statistics from Allen Data

# %%
# Compute population-level summary statistics from Allen Cell Types
# These represent the 'micro-scale' reference features

allen_numeric_cols = [f for f, _ in plot_features if f in cortical_df.columns]

allen_summary = cortical_df[allen_numeric_cols].describe().T[['mean', 'std', '50%']]
allen_summary.columns = ['allen_mean', 'allen_std', 'allen_median']

print('Allen Cell Types — Population Summary Statistics:')
print(allen_summary.round(4))
# Out:
# Allen Cell Types — Population Summary Statistics:
#                     allen_mean  allen_std  allen_median
# peak_v_long_square     29.9823    11.4490       31.6562
# tau                    17.9407    10.6262       16.3848
# adaptation              0.0528     0.1006        0.0227

# %% [markdown]
# ### 4.2 Feature Mapping: Micro → Macro

# %%
# Conceptual mapping between Allen features and EEG features
# Based on literature linking single-neuron properties to population oscillations

feature_mapping = {
    'avg_firing_rate':     'mean_alpha_power',         # Higher firing → higher alpha
    'mean_isi':            'mean_theta_power',          # Longer ISI → more theta
    'peak_v_long_square':  'mean_beta_power',           # AP amplitude → beta power
    'adaptation':          'frontal_alpha_asymmetry',   # Adaptation → asymmetry
    'input_resistance':    'theta_alpha_ratio',         # Resistance → theta/alpha
}

print('Proposed Feature Mapping (Micro → Macro):')
print('=' * 60)
for allen_feat, eeg_feat in feature_mapping.items():
    print(f'  Allen: {allen_feat:<35} → EEG: {eeg_feat}')
# Out:
# Proposed Feature Mapping (Micro → Macro):
# ============================================================
#   Allen: avg_firing_rate                     → EEG: mean_alpha_power
#   Allen: mean_isi                            → EEG: mean_theta_power
#   Allen: peak_v_long_square                  → EEG: mean_beta_power
#   Allen: adaptation                          → EEG: frontal_alpha_asymmetry
#   Allen: input_resistance                    → EEG: theta_alpha_ratio

# %%
# Simulate subject-level Allen-like features for correlation analysis
# In real analysis: use Allen SDK to get per-cell-type distributions
# and map to subjects via literature-based priors

np.random.seed(42)

# Simulate micro-scale features per subject (proxy from Allen distributions)
allen_proxy = pd.DataFrame({
    'subject_id': eeg_features_df['subject_id'],
    'label': eeg_features_df['label'],
    # MDD associated with lower firing rates, longer ISI (literature-based)
    'avg_firing_rate': np.concatenate([
        np.random.normal(4.0, 1.5, 53),
        np.random.normal(6.5, 1.5, 53)
    ]),
    'mean_isi': np.concatenate([
        np.random.normal(280, 60, 53),
        np.random.normal(200, 50, 53)
    ]),
    'peak_v_long_square': np.concatenate([
        np.random.normal(38, 5, 53),
        np.random.normal(42, 4, 53)
    ]),
})

# Merge with EEG features
combined_df = eeg_features_df.merge(allen_proxy, on=['subject_id', 'label'])
print(f'Combined dataset shape: {combined_df.shape}')
combined_df.head()
# Out:
# Combined dataset shape: (106, 10)
#   subject_id  label  mean_alpha_power  mean_theta_power  mean_beta_power  \
# 0    sub_000      1          0.899343          1.865856         0.743100
# 1    sub_001      1          0.772347          1.352373         0.697709
# 2    sub_002      1          0.929538          1.377265         0.552710
# 3    sub_003      1          1.104606          1.277666         0.713845
# 4    sub_004      1          0.753169          0.724369         0.484076
#
#    frontal_alpha_asymmetry  theta_alpha_ratio  avg_firing_rate    mean_isi  \
# 0                 0.348625           1.958150         4.745071  393.171154
# 1                 0.280479           2.247453         3.792604  290.474669
# 2                 0.314549           1.314031         4.971533  295.453023
# 3                 0.389274           1.974421         6.284545  275.533245
# 4                 0.177267           2.123370         3.648770  164.873727
#
#    peak_v_long_square
# 0           42.770009
# 1           41.256956
# 2           36.423654
# 3           41.794846
# 4           34.135874

# %% [markdown]
# ### 4.3 Spearman Correlation Analysis

# %%
# Compute Spearman correlations between Allen features and EEG features
allen_feat_cols = ['avg_firing_rate', 'mean_isi', 'peak_v_long_square']
eeg_feat_cols_sub = ['mean_alpha_power', 'mean_theta_power', 
                      'frontal_alpha_asymmetry', 'theta_alpha_ratio']

corr_results = []

for af in allen_feat_cols:
    for ef in eeg_feat_cols_sub:
        rho, p = spearmanr(combined_df[af], combined_df[ef])
        corr_results.append({
            'Allen Feature': af,
            'EEG Feature': ef,
            'Spearman_rho': rho,
            'p_value': p
        })

corr_df = pd.DataFrame(corr_results)

# FDR correction
_, p_corrected, _, _ = multipletests(corr_df['p_value'], method='fdr_bh')
corr_df['p_corrected'] = p_corrected
corr_df['significant'] = corr_df['p_corrected'] < 0.05

print('Spearman Correlation Results (with FDR correction):')
print(corr_df.round(4).to_string())
# Out:
# Spearman Correlation Results (with FDR correction):
#          Allen Feature              EEG Feature  Spearman_rho  p_value  p_corrected  significant
# 0      avg_firing_rate         mean_alpha_power        0.9962   0.0000       0.0000         True
# 1      avg_firing_rate         mean_theta_power       -0.4549   0.0000       0.0000         True
# 2      avg_firing_rate  frontal_alpha_asymmetry       -0.5316   0.0000       0.0000         True
# 3      avg_firing_rate        theta_alpha_ratio       -0.5585   0.0000       0.0000         True
# 4             mean_isi         mean_alpha_power       -0.4523   0.0000       0.0000         True
# 5             mean_isi         mean_theta_power        0.9978   0.0000       0.0000         True
# 6             mean_isi  frontal_alpha_asymmetry        0.4562   0.0000       0.0000         True
# 7             mean_isi        theta_alpha_ratio        0.3829   0.0001       0.0001         True
# 8   peak_v_long_square         mean_alpha_power        0.4035   0.0000       0.0000         True
# 9   peak_v_long_square         mean_theta_power       -0.4082   0.0000       0.0000         True
# 10  peak_v_long_square  frontal_alpha_asymmetry       -0.3076   0.0013       0.0013         True
# 11  peak_v_long_square        theta_alpha_ratio       -0.4105   0.0000       0.0000         True

# %%
# Visualize as a heatmap
corr_pivot = corr_df.pivot(index='Allen Feature', 
                            columns='EEG Feature', 
                            values='Spearman_rho')

sig_pivot = corr_df.pivot(index='Allen Feature',
                           columns='EEG Feature',
                           values='significant')

plt.figure(figsize=(9, 4))
ax = sns.heatmap(corr_pivot, annot=True, fmt='.3f', cmap='coolwarm',
                  center=0, vmin=-1, vmax=1, linewidths=0.5,
                  cbar_kws={'label': 'Spearman ρ'})

# Mark significant correlations with asterisk
for i in range(sig_pivot.shape[0]):
    for j in range(sig_pivot.shape[1]):
        if sig_pivot.iloc[i, j]:
            ax.text(j + 0.8, i + 0.2, '*', fontsize=14, color='black', fontweight='bold')

plt.title('Cross-Scale Correlation: Allen Cell Features vs EEG Biomarkers\n(* = significant after FDR correction)', 
          fontsize=11)
plt.tight_layout()
plt.savefig('cross_scale_correlation.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## PART 5: Summary & Conclusions

# %%
print('=' * 60)
print('COGS 138 GROUP 7 — PROJECT SUMMARY')
print('=' * 60)

print(f'''
Research Question:
Are electrophysiological features from the Allen Cell Types Database 
reflected in resting-state EEG biomarkers for MDD?

Datasets:
  - Allen Cell Types Database (n = {len(cortical_df) if len(cortical_df) > 0 else 'TBD'} mouse cortical neurons)
  - MODMA EEG Dataset (n = {len(eeg_features_df)} subjects: 53 MDD, 53 healthy)

Key Findings:
  1. EEG Decoding Accuracy:   {cv_scores.mean():.1%} ± {cv_scores.std():.1%}
  2. Most predictive EEG feature: {coef_df.iloc[-1]["Feature"]}
  3. Significant cross-scale correlations: {corr_df["significant"].sum()} / {len(corr_df)}

Limitations:
  - Cross-species comparison (mouse → human)
  - Different measurement scales (single neuron → scalp EEG)
  - Synthetic data used for demonstration (replace with real MODMA)

Next Steps:
  - Download and process real MODMA EEG data
  - Refine Allen cell type filtering (focus on PFC-relevant cells)
  - Add ICA artifact removal to EEG preprocessing
  - Try non-linear classifiers (SVM, Random Forest)
''')

print('=' * 60)
# Out:
# ============================================================
# COGS 138 GROUP 7 — PROJECT SUMMARY
# ============================================================
#
# Research Question:
# Are electrophysiological features from the Allen Cell Types Database
# reflected in resting-state EEG biomarkers for MDD?
#
# Datasets:
#   - Allen Cell Types Database (n = 1920 mouse cortical neurons)
#   - MODMA EEG Dataset (n = 106 subjects: 53 MDD, 53 healthy)
#
# Key Findings:
#   1. EEG Decoding Accuracy:   98.1% ± 2.3%
#   2. Most predictive EEG feature: theta_alpha_ratio
#   3. Significant cross-scale correlations: 12 / 12
#
# Limitations:
#   - Cross-species comparison (mouse → human)
#   - Different measurement scales (single neuron → scalp EEG)
#   - Synthetic data used for demonstration (replace with real MODMA)
#
# Next Steps:
#   - Download and process real MODMA EEG data
#   - Refine Allen cell type filtering (focus on PFC-relevant cells)
#   - Add ICA artifact removal to EEG preprocessing
#   - Try non-linear classifiers (SVM, Random Forest)
#
# ============================================================

# %% [markdown]
# ---
# ## References
#
# 1. Quinn, G. M. V. (2024). Resting-state EEG microstate features for major depressive disorder classification. *CUNY Academic Works.*
# 2. Siebenbühner, F., et al. (2026). Brain anatomy and molecular signaling predict neurophysiological dynamics across the lifespan. *bioRxiv.*
# 3. Gouwens, N. W., et al. (2019). Classification of electrophysiological and morphological neuron types in the mouse visual cortex. *Nature Neuroscience.*
# 4. Wu, X., et al. (2021). Resting-state EEG signal for MDD detection. *Biosensors, MDPI.*
# 5. Yang, et al. (2023). Depression detection based on EEG signals in multi brain regions. *Journal of Integrative Neuroscience.*
